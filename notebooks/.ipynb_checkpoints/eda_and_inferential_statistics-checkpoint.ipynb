# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import rcParams
import load_processed_data as ld
from definitions import REPO_ROOT_PATH, PROCESSED_DATA_PATH
from keras.preprocessing.image import img_to_array, load_img, array_to_img
import cv2
import os
import shutil
import subprocess

# %%
# configure matplotlib settings
rcParams.update({'font.size' : 18})

# %%
# set path for output image files
figure_output_path = REPO_ROOT_PATH + "reports/figures/"

# %%
# load train, validation, test dataframes with the processed data
_, _, df_train = ld.load_train_data()
_, _, df_val = ld.load_validation_data()
_, _, df_test = ld.load_test_data()

df_train['set'] = 'train'
df_val['set'] = 'validation'
df_test['set'] = 'test'

# concatenate the dataframes into one with all processed data
df = pd.concat([df_train, df_val, df_test], ignore_index=True)

# %%
df_class_list = df.image_class.unique().tolist()

# initialize dicts of pixel arrays 
X_rgb = {}
X_avg_rgb = {}
X_avg_bw = {}

# fill dicts with pixel arrays keyed by class
for c in df_class_list:
    X_rgb[c] = np.array(df.pixel_array_custom_image_size[df.image_class == c].tolist())
    X_avg_rgb[c] = np.mean(X_rgb[c], axis=0)
    X_avg_bw[c] = cv2.cvtColor(X_avg_rgb[c], cv2.COLOR_RGB2GRAY)

# %%
fig, ax = plt.subplots(nrows=1, ncols=3, figsize=(13,4))

for ic, c in enumerate(df_class_list):
    ax[ic].imshow(X_avg_bw[c], cmap='gray')
    ax[ic].set_yticks([])
    ax[ic].set_xticks([])
    ax[ic].set_xlabel(c.replace("_", " ").title())

fig.suptitle('Mean Images (%i x %i)' % (X_avg_bw['normal'].shape[0], X_avg_bw['normal'].shape[1]))

fig.savefig(figure_output_path + 'mean_images.png')

# %%
fig, ax = plt.subplots(nrows=3, ncols=1, sharex=True, sharey=True, figsize=(8,10))

for ic, c in enumerate(df_class_list):
    ax[ic].hist(X_avg_bw[c].ravel(), bins=256, range=[0, 256], color='grey')
    ax[ic].text(-5, 600, c.replace("_", " "), color='grey')
ax[0].set_title('Intensity Histograms of Mean Images')
ax[-1].set_xlabel('Pixel Intensity')
fig.text(0.02, 0.5, 'Frequency Count', ha='center', va='center', rotation='vertical')

fig.savefig(figure_output_path + 'mean_images_intensity_histograms.png')

# %%
train_image_filepath = PROCESSED_DATA_PATH + "train_data/image_files/"

filepath_examples = {}

filepath_examples['normal'] = train_image_filepath + "NORMAL-2504415-0001.jpeg"
filepath_examples['bacterial_pneumonia'] = train_image_filepath + "BACTERIA-558657-0001.jpeg"
filepath_examples['viral_pneumonia'] = train_image_filepath + "VIRUS-1801584-0006.jpeg"

for k, fp in filepath_examples.items():
    shutil.copy(fp, figure_output_path + k + '_example.jpeg')

# %%
df_customize = df.copy()
df_customize['image_class'] = df_customize['image_class'].str.replace('_', ' ')

df_counts = df_customize.groupby(['set', 'image_class']).count()[['pixel_array_custom_image_size']]
df_counts.columns = ['Count']
df_counts.index.rename(['Set', 'Image Class'], inplace=True)


df_counts.reindex(index=['train','validation','test'], level=0).reindex(index=['bacterial pneumonia', 'viral pneumonia', 'normal'], level=1)
# Out:
#                                 Count
# Set        Image Class
# train      bacterial pneumonia   1904
#            viral pneumonia       1009
#            normal                1012
# validation bacterial pneumonia    634
#            viral pneumonia        336
#            normal                 337
# test       bacterial pneumonia    242
#            viral pneumonia        148
#            normal                 234

# %%
df_counts.to_csv(figure_output_path + 'file_counts.csv')
